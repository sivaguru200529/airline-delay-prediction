# %% [markdown]
# # 01 - Historical Flight Data Exploration
#
# ## Objectives:
# - Load raw public historical flight dataset (BTS TranStats / Kaggle 2015).
# - Inspect schema, column data types, and initial record samples.
# - Assess initial missingness, duplicate rates, and data anomalies.
# - Identify post-flight columns for leakage prevention.

# %%
import sys
from pathlib import Path

# Ensure project root is on sys.path
project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

import pandas as pd
from src.utils.config import get_config
from src.data.ingestion import FlightDataIngestor

config = get_config()
print(f"Project root: {config.project_root}")
print(f"Raw data directory: {config.data_raw_dir}")
