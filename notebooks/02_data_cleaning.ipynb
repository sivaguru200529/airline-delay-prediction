# %% [markdown]
# # 02 - Data Cleaning, Validation & Leakage Prevention
#
# ## Objectives:
# - Run DataQualityValidator checks on mapped flight data.
# - Audit missing values, invalid airport codes, negative distances, and timestamps.
# - Segregate cancelled and diverted flights.
# - Construct the binary target: `delay_target = 1 if arrival_delay >= 15 else 0`.
# - Purge post-flight operational columns to construct the pre-departure feature view.

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.data.ingestion import FlightDataIngestor
from src.data.validation import DataQualityValidator
from src.data.preprocessing import FlightDataPreprocessor

print("Cleaning & validation components loaded successfully.")
